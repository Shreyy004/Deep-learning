# %%
#SOFTMAX PLUS
import numpy as np
import matplotlib.pyplot as plt

# Softplus function and its derivative
def softplus(x):
    return np.log(1 + np.exp(x))

def softplus_derivative(x):
    return 1 / (1 + np.exp(-x))

# Generate input data
X = np.linspace(-10, 10, 100)
y = softplus(X)

z = softplus_derivative(X)

# Plot Softplus function
plt.figure(figsize=(3, 1))
plt.plot(X, y, label='Softplus Function', color='red')
plt.title('Softplus Activation Function')
plt.xlabel('Input')
plt.ylabel('Output')
plt.grid(True)
plt.legend()
plt.show()

# Plot derivative of Softplus
plt.figure(figsize=(3, 1))
plt.plot(X, z, label='Derivative of Softplus Function', color='blue')
plt.title('Derivative of Softplus Activation Function')
plt.xlabel('Input')
plt.ylabel('Output')
plt.grid(True)
plt.legend()
plt.show()

# %%
f(x)=ln(1+e^x)
Output range is [0,∞), similar to ReLU.
For large 
𝑥
x, Softplus behaves like ReLU:
f(x)≈xfor x→∞
For small 
𝑥
x, it behaves like a small positive constant:
f(x)≈0for x→−∞      

Advantages of Softplus
Smooth Gradient:

The smooth nature of Softplus ensures no abrupt changes in gradients, unlike ReLU.
Avoids Dead Neurons:

Unlike ReLU, Softplus does not result in neurons that always output zero because it assigns small positive values for negative inputs.
Mathematical Elegance:

Softplus is continuously differentiable, which is advantageous in certain optimization scenarios.
Disadvantages of Softplus
Computational Complexity:

Computing the natural logarithm and exponentials is more computationally expensive than the simple operations in ReLU.
Vanishing Gradient for Large Negative Inputs:

For very negative 
≈0), leading to slow learning in those regions.
Unbounded Output for Positive Inputs:

Similar to ReLU, the output can grow indefinitely for large positive 
x, which might destabilize some training processes.

# %%
import os
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from urllib.request import urlretrieve
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.utils import plot_model

# %%
def load_demand_dataset():
    dataset_url = "https://archive.ics.uci.edu/ml/machine-learning-databases/00409/Daily_Demand_Forecasting_Orders.csv"
    local_filename = "Daily_Demand_Forecasting_Orders.csv"
    if not os.path.exists(local_filename):
        print("Downloading dataset...")
        urlretrieve(dataset_url, local_filename)
    df = pd.read_csv(local_filename, delimiter=';', decimal=',')
    print(f"Dataset loaded with shape: {df.shape}")
    return df

# %%
def create_sequences(X, y, seq_length):
    X_seq, y_seq = [], []
    for i in range(len(X) - seq_length):
        X_seq.append(X[i:i + seq_length])
        y_seq.append(y[i + seq_length])
    return np.array(X_seq), np.array(y_seq)

# %%
def build_lstm_model(sequence_length, n_features):
    model = Sequential([
        LSTM(64, return_sequences=True, input_shape=(sequence_length, n_features), recurrent_dropout=0.1),
        LSTM(64, return_sequences=True, recurrent_dropout=0.1),
        LSTM(64, recurrent_dropout=0.1),
        Dropout(0.2),
        Dense(1)
    ])
    model.compile(optimizer='adam', loss='mean_squared_error')
    print(model.summary())
    return model

# %%
def calculate_metrics(actual, predicted):
    metrics = {
        'RMSE': math.sqrt(mean_squared_error(actual, predicted)),
        'MAE': mean_absolute_error(actual, predicted),
        'R²': r2_score(actual, predicted),
        'MAPE': np.mean(np.abs((actual - predicted) / (actual + 1e-5))) * 100
    }
    return metrics

# %%
def main():
    df = load_demand_dataset()
    
    # Feature and target selection
    features = df.drop(columns=['Target (Total orders)'])
    target = df['Target (Total orders)']

    # Scaling
    X_scaler = MinMaxScaler()
    y_scaler = MinMaxScaler()
    X_scaled = X_scaler.fit_transform(features)
    y_scaled = y_scaler.fit_transform(target.values.reshape(-1, 1))

    # Parameters
    sequence_length = 7
    train_size = int(len(X_scaled) * 0.8)

    # Train-test split
    X_train_data = X_scaled[:train_size]
    X_test_data = X_scaled[train_size - sequence_length:]
    y_train_data = y_scaled[:train_size]
    y_test_data = y_scaled[train_size - sequence_length:]

    # Create sequences
    X_train, y_train = create_sequences(X_train_data, y_train_data, sequence_length)
    X_test, y_test = create_sequences(X_test_data, y_test_data, sequence_length)

    print(f"Training data shape: {X_train.shape}")
    print(f"Testing data shape: {X_test.shape}")

    # Model building
    model = build_lstm_model(sequence_length, X_train.shape[2])
    # plot_model(model, to_file='lstm_model.png', show_shapes=True, show_layer_names=True, rankdir='LR')

    # Callbacks
    early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
    lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=0.0001)

    # Training
    history = model.fit(
        X_train, y_train,
        epochs=100,
        batch_size=16,
        validation_split=0.2,
        callbacks=[early_stop, lr_scheduler],
        verbose=1
    )

    # Predictions
    train_predictions = model.predict(X_train)
    test_predictions = model.predict(X_test)

    # Inverse transform
    train_predictions = y_scaler.inverse_transform(train_predictions)
    y_train_inv = y_scaler.inverse_transform(y_train)
    test_predictions = y_scaler.inverse_transform(test_predictions)
    y_test_inv = y_scaler.inverse_transform(y_test)

    # Metrics
    train_metrics = calculate_metrics(y_train_inv, train_predictions)
    test_metrics = calculate_metrics(y_test_inv, test_predictions)
    print("Train Metrics:", train_metrics)
    print("Test Metrics:", test_metrics)

    # Plot training loss
    plt.figure(figsize=(12, 6))
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Model Loss During Training')
    plt.xlabel('Epoch')
    plt.ylabel('Loss (MSE)')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.savefig('training_loss.png')
    plt.show()

    # Plot predictions
    plt.figure(figsize=(14, 7))
    plt.plot(y_test_inv, label='Actual Demand', color='blue', alpha=0.7)
    plt.plot(test_predictions, label='Predicted Demand', color='red', alpha=0.7)
    plt.title('Actual vs. Predicted Demand - Test Data')
    plt.xlabel('Time')
    plt.ylabel('Number of Orders')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.savefig('test_predictions.png')
    plt.show()

    # Plot metrics
    metrics_names = list(train_metrics.keys())
    train_values = [train_metrics[m] for m in metrics_names]
    test_values = [test_metrics[m] for m in metrics_names]
    x = np.arange(len(metrics_names))
    width = 0.35

    plt.figure(figsize=(12, 8))
    plt.bar(x - width/2, train_values, width, label='Training')
    plt.bar(x + width/2, test_values, width, label='Testing')
    plt.title('Performance Metrics Comparison')
    plt.xticks(x, metrics_names)
    plt.ylabel('Value')
    plt.legend()
    plt.grid(True, axis='y')
    plt.tight_layout()
    plt.savefig('performance_metrics.png')
    plt.show()

# %%
if __name__ == "__main__":
    main()
# Out:
# Dataset loaded with shape: (60, 13)
# Training data shape: (41, 7, 12)
# Testing data shape: (12, 7, 12)
# c:\users\hp\appdata\local\programs\python\python39\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 7, 64)               │          19,712 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 7, 64)               │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_2 (LSTM)                        │ (None, 64)                  │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 85,825 (335.25 KB)
#  Trainable params: 85,825 (335.25 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# You must install graphviz (see instructions at https://graphviz.gitlab.io/download/) for `plot_model` to work.
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 604ms/step - loss: 0.1477 - val_loss: 0.0693 - learning_rate: 0.0010
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0852 - val_loss: 0.0291 - learning_rate: 0.0010
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0449 - val_loss: 0.0254 - learning_rate: 0.0010
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0436 - val_loss: 0.0605 - learning_rate: 0.0010
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0616 - val_loss: 0.0446 - learning_rate: 0.0010
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0341 - val_loss: 0.0262 - learning_rate: 0.0010
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0334 - val_loss: 0.0203 - learning_rate: 0.0010
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0292 - val_loss: 0.0204 - learning_rate: 0.0010
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0350 - val_loss: 0.0205 - learning_rate: 0.0010
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0371 - val_loss: 0.0199 - learning_rate: 0.0010
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0426 - val_loss: 0.0199 - learning_rate: 0.0010
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0336 - val_loss: 0.0218 - learning_rate: 0.0010
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0283 - val_loss: 0.0249 - learning_rate: 0.0010
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0368 - val_loss: 0.0256 - learning_rate: 0.0010
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0412 - val_loss: 0.0241 - learning_rate: 0.0010
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0415 - val_loss: 0.0225 - learning_rate: 5.0000e-04
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0291 - val_loss: 0.0204 - learning_rate: 5.0000e-04
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0253 - val_loss: 0.0194 - learning_rate: 5.0000e-04
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0308 - val_loss: 0.0188 - learning_rate: 5.0000e-04
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0280 - val_loss: 0.0187 - learning_rate: 5.0000e-04
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0313 - val_loss: 0.0187 - learning_rate: 5.0000e-04
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0349 - val_loss: 0.0191 - learning_rate: 5.0000e-04
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0298 - val_loss: 0.0197 - learning_rate: 5.0000e-04
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0268 - val_loss: 0.0198 - learning_rate: 5.0000e-04
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0280 - val_loss: 0.0204 - learning_rate: 5.0000e-04
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0314 - val_loss: 0.0207 - learning_rate: 2.5000e-04
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0379 - val_loss: 0.0207 - learning_rate: 2.5000e-04
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0372 - val_loss: 0.0204 - learning_rate: 2.5000e-04
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0268 - val_loss: 0.0201 - learning_rate: 2.5000e-04
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0314 - val_loss: 0.0195 - learning_rate: 2.5000e-04
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0353 - val_loss: 0.0192 - learning_rate: 1.2500e-04
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0264 - val_loss: 0.0189 - learning_rate: 1.2500e-04
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0363 - val_loss: 0.0187 - learning_rate: 1.2500e-04
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0215 - val_loss: 0.0184 - learning_rate: 1.2500e-04
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0369 - val_loss: 0.0182 - learning_rate: 1.2500e-04
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0331 - val_loss: 0.0182 - learning_rate: 1.2500e-04
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0260 - val_loss: 0.0182 - learning_rate: 1.2500e-04
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0304 - val_loss: 0.0182 - learning_rate: 1.2500e-04
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0266 - val_loss: 0.0182 - learning_rate: 1.2500e-04
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0261 - val_loss: 0.0181 - learning_rate: 1.2500e-04
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0234 - val_loss: 0.0181 - learning_rate: 1.0000e-04
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0245 - val_loss: 0.0181 - learning_rate: 1.0000e-04
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0308 - val_loss: 0.0182 - learning_rate: 1.0000e-04
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0214 - val_loss: 0.0182 - learning_rate: 1.0000e-04
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0324 - val_loss: 0.0183 - learning_rate: 1.0000e-04
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0292 - val_loss: 0.0185 - learning_rate: 1.0000e-04
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0253 - val_loss: 0.0185 - learning_rate: 1.0000e-04
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0361 - val_loss: 0.0185 - learning_rate: 1.0000e-04
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0211 - val_loss: 0.0186 - learning_rate: 1.0000e-04
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0327 - val_loss: 0.0187 - learning_rate: 1.0000e-04
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0278 - val_loss: 0.0189 - learning_rate: 1.0000e-04
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0312 - val_loss: 0.0189 - learning_rate: 1.0000e-04
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0390 - val_loss: 0.0189 - learning_rate: 1.0000e-04
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0254 - val_loss: 0.0186 - learning_rate: 1.0000e-04
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0334 - val_loss: 0.0185 - learning_rate: 1.0000e-04
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0306 - val_loss: 0.0182 - learning_rate: 1.0000e-04
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0213 - val_loss: 0.0178 - learning_rate: 1.0000e-04
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0285 - val_loss: 0.0177 - learning_rate: 1.0000e-04
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0231 - val_loss: 0.0176 - learning_rate: 1.0000e-04
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0281 - val_loss: 0.0175 - learning_rate: 1.0000e-04
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0341 - val_loss: 0.0174 - learning_rate: 1.0000e-04
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0280 - val_loss: 0.0173 - learning_rate: 1.0000e-04
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0349 - val_loss: 0.0172 - learning_rate: 1.0000e-04
# Epoch 64/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0310 - val_loss: 0.0172 - learning_rate: 1.0000e-04
# Epoch 65/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0301 - val_loss: 0.0172 - learning_rate: 1.0000e-04
# Epoch 66/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0198 - val_loss: 0.0171 - learning_rate: 1.0000e-04
# Epoch 67/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0201 - val_loss: 0.0171 - learning_rate: 1.0000e-04
# Epoch 68/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0320 - val_loss: 0.0172 - learning_rate: 1.0000e-04
# Epoch 69/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0259 - val_loss: 0.0172 - learning_rate: 1.0000e-04
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0266 - val_loss: 0.0173 - learning_rate: 1.0000e-04
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0208 - val_loss: 0.0173 - learning_rate: 1.0000e-04
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0252 - val_loss: 0.0174 - learning_rate: 1.0000e-04
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0220 - val_loss: 0.0173 - learning_rate: 1.0000e-04
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0312 - val_loss: 0.0173 - learning_rate: 1.0000e-04
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0350 - val_loss: 0.0172 - learning_rate: 1.0000e-04
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0333 - val_loss: 0.0172 - learning_rate: 1.0000e-04
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0382 - val_loss: 0.0170 - learning_rate: 1.0000e-04
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0324 - val_loss: 0.0167 - learning_rate: 1.0000e-04
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0312 - val_loss: 0.0164 - learning_rate: 1.0000e-04
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0312 - val_loss: 0.0163 - learning_rate: 1.0000e-04
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0294 - val_loss: 0.0163 - learning_rate: 1.0000e-04
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0249 - val_loss: 0.0163 - learning_rate: 1.0000e-04
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0248 - val_loss: 0.0163 - learning_rate: 1.0000e-04
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0291 - val_loss: 0.0162 - learning_rate: 1.0000e-04
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0295 - val_loss: 0.0162 - learning_rate: 1.0000e-04
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0232 - val_loss: 0.0161 - learning_rate: 1.0000e-04
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0273 - val_loss: 0.0161 - learning_rate: 1.0000e-04
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0276 - val_loss: 0.0162 - learning_rate: 1.0000e-04
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0295 - val_loss: 0.0163 - learning_rate: 1.0000e-04
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0211 - val_loss: 0.0163 - learning_rate: 1.0000e-04
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0245 - val_loss: 0.0163 - learning_rate: 1.0000e-04
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0298 - val_loss: 0.0164 - learning_rate: 1.0000e-04
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0300 - val_loss: 0.0165 - learning_rate: 1.0000e-04
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0239 - val_loss: 0.0164 - learning_rate: 1.0000e-04
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0235 - val_loss: 0.0163 - learning_rate: 1.0000e-04
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0337 - val_loss: 0.0163 - learning_rate: 1.0000e-04
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0283 - val_loss: 0.0163 - learning_rate: 1.0000e-04
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0267 - val_loss: 0.0163 - learning_rate: 1.0000e-04
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0250 - val_loss: 0.0162 - learning_rate: 1.0000e-04
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0224 - val_loss: 0.0161 - learning_rate: 1.0000e-04
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 470ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step

# %%
X_train.shape → (num_sequences, sequence_length, n_features)

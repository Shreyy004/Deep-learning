# %%
import os
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from urllib.request import urlretrieve

# Load dataset
def load_demand_dataset():
    dataset_url = "https://archive.ics.uci.edu/ml/machine-learning-databases/00409/Daily_Demand_Forecasting_Orders.csv"
    local_filename = "Daily_Demand_Forecasting_Orders.csv"
    
    if not os.path.exists(local_filename):
        print("Downloading dataset...")
        urlretrieve(dataset_url, local_filename)
    
    df = pd.read_csv(local_filename, delimiter=';', decimal=',')
    print(f"Dataset loaded with shape: {df.shape}")
    return df

def create_sequences(X, y, seq_length):
    X_seq, y_seq = [], []
    for i in range(len(X) - seq_length):
        X_seq.append(X[i:i + seq_length])
        y_seq.append(y[i + seq_length])
    return np.array(X_seq), np.array(y_seq)

df = load_demand_dataset()

df = df.iloc[:, 1:]  # Drop the first column if it's unnecessary

y = df.iloc[:, -1].values.reshape(-1, 1)  # Target variable

scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()

X_scaled = scaler_X.fit_transform(df)
y_scaled = scaler_y.fit_transform(y)

sequence_length = 7  # One week lookback
train_size = int(len(X_scaled) * 0.8)

X_train_data = X_scaled[:train_size]
X_test_data = X_scaled[train_size - sequence_length:]
y_train_data = y_scaled[:train_size]
y_test_data = y_scaled[train_size - sequence_length:]

X_train, y_train = create_sequences(X_train_data, y_train_data, sequence_length)
X_test, y_test = create_sequences(X_test_data, y_test_data, sequence_length)

print(f"Training data shape: {X_train.shape}")
print(f"Testing data shape: {X_test.shape}")

# Build LSTM model
def build_lstm_model(sequence_length, n_features):
    model = Sequential([
        LSTM(64, return_sequences=True, input_shape=(sequence_length, n_features), recurrent_dropout=0.1),
        LSTM(64, return_sequences=True, recurrent_dropout=0.1),
        LSTM(64, recurrent_dropout=0.1),
        Dropout(0.2),
        Dense(1)
    ])
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

model = build_lstm_model(sequence_length, X_train.shape[2])
print(model.summary())

# Visualize Model
# from tensorflow.keras.utils import plot_model
# plot_model(model, to_file='lstm_model.png', show_shapes=True, show_layer_names=True, rankdir='LR')

# Callbacks
early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=0.0001)

# Train Model
history = model.fit(
    X_train, y_train,
    epochs=100,
    batch_size=16,
    validation_split=0.2,
    callbacks=[early_stop, lr_scheduler],
    verbose=1
)

# Make predictions
train_predictions = model.predict(X_train)
test_predictions = model.predict(X_test)

# Inverse transform predictions
train_predictions = scaler_y.inverse_transform(train_predictions)
y_train_inv = scaler_y.inverse_transform(y_train)
test_predictions = scaler_y.inverse_transform(test_predictions)
y_test_inv = scaler_y.inverse_transform(y_test)

# Calculate metrics
def calculate_metrics(actual, predicted):
    return {
        'RMSE': math.sqrt(mean_squared_error(actual, predicted)),
        'MAE': mean_absolute_error(actual, predicted),
        'R²': r2_score(actual, predicted),
        'MAPE': np.mean(np.abs((actual - predicted) / (actual + 1e-5))) * 100
    }

train_metrics = calculate_metrics(y_train_inv, train_predictions)
test_metrics = calculate_metrics(y_test_inv, test_predictions)
print("Train Metrics:", train_metrics)
print("Test Metrics:", test_metrics)

# Plot Training Loss
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss During Training')
plt.ylabel('Loss (MSE)')
plt.xlabel('Epoch')
plt.legend()
plt.grid(True)
plt.savefig('training_loss.png')
plt.show()

# Plot Actual vs Predicted
plt.figure(figsize=(14, 7))
plt.plot(y_test_inv, label='Actual Demand', color='blue', alpha=0.7)
plt.plot(test_predictions, label='Predicted Demand', color='red', alpha=0.7)
plt.title('Actual vs. Predicted Demand - Test Data')
plt.ylabel('Number of Orders')
plt.xlabel('Time')
plt.legend()
plt.grid(True)
plt.savefig('test_predictions.png')
plt.show()

# Performance Metrics Comparison
metrics_names = list(train_metrics.keys())
train_values = [train_metrics[m] for m in metrics_names]
test_values = [test_metrics[m] for m in metrics_names]
plt.figure(figsize=(12, 8))
x = np.arange(len(metrics_names))
width = 0.35
plt.bar(x - width/2, train_values, width, label='Training')
plt.bar(x + width/2, test_values, width, label='Testing')
plt.title('Performance Metrics Comparison')
plt.xticks(x, metrics_names)
plt.ylabel('Value')
plt.legend()
plt.grid(True, axis='y')
plt.savefig('performance_metrics.png')
plt.show()
# Out:
# Downloading dataset...
# Dataset loaded with shape: (60, 13)
# Training data shape: (41, 7, 12)
# Testing data shape: (12, 7, 12)
# C:\Users\Lenovo\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 7, 64)               │          19,712 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 7, 64)               │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_2 (LSTM)                        │ (None, 64)                  │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 85,825 (335.25 KB)
#  Trainable params: 85,825 (335.25 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 934ms/step - loss: 0.1525 - val_loss: 0.0694 - learning_rate: 0.0010
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0799 - val_loss: 0.0292 - learning_rate: 0.0010
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0646 - val_loss: 0.0240 - learning_rate: 0.0010
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0395 - val_loss: 0.0658 - learning_rate: 0.0010
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.0574 - val_loss: 0.0648 - learning_rate: 0.0010
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0441 - val_loss: 0.0362 - learning_rate: 0.0010
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0412 - val_loss: 0.0212 - learning_rate: 0.0010
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0324 - val_loss: 0.0202 - learning_rate: 0.0010
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 0.0325 - val_loss: 0.0220 - learning_rate: 0.0010
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0469 - val_loss: 0.0217 - learning_rate: 0.0010
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0394 - val_loss: 0.0202 - learning_rate: 0.0010
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0385 - val_loss: 0.0199 - learning_rate: 0.0010
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0443 - val_loss: 0.0222 - learning_rate: 0.0010
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0277 - val_loss: 0.0263 - learning_rate: 0.0010
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0388 - val_loss: 0.0289 - learning_rate: 0.0010
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - loss: 0.0291 - val_loss: 0.0271 - learning_rate: 0.0010
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0338 - val_loss: 0.0233 - learning_rate: 0.0010
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0379 - val_loss: 0.0216 - learning_rate: 5.0000e-04
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0270 - val_loss: 0.0202 - learning_rate: 5.0000e-04
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0281 - val_loss: 0.0196 - learning_rate: 5.0000e-04
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0344 - val_loss: 0.0193 - learning_rate: 5.0000e-04
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0303 - val_loss: 0.0192 - learning_rate: 5.0000e-04
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 0.0318 - val_loss: 0.0192 - learning_rate: 5.0000e-04
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0393 - val_loss: 0.0196 - learning_rate: 5.0000e-04
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0363 - val_loss: 0.0202 - learning_rate: 5.0000e-04
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - loss: 0.0360 - val_loss: 0.0208 - learning_rate: 5.0000e-04
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.0280 - val_loss: 0.0207 - learning_rate: 5.0000e-04
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 0.0370 - val_loss: 0.0206 - learning_rate: 2.5000e-04
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 0.0352 - val_loss: 0.0203 - learning_rate: 2.5000e-04
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0277 - val_loss: 0.0199 - learning_rate: 2.5000e-04
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 0.0289 - val_loss: 0.0196 - learning_rate: 2.5000e-04
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - loss: 0.0307 - val_loss: 0.0194 - learning_rate: 2.5000e-04
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0348 - val_loss: 0.0193 - learning_rate: 1.2500e-04
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0293 - val_loss: 0.0191 - learning_rate: 1.2500e-04
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 0.0322 - val_loss: 0.0190 - learning_rate: 1.2500e-04
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0403 - val_loss: 0.0190 - learning_rate: 1.2500e-04
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0394 - val_loss: 0.0190 - learning_rate: 1.2500e-04
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.0309 - val_loss: 0.0189 - learning_rate: 1.2500e-04
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0270 - val_loss: 0.0188 - learning_rate: 1.2500e-04
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0347 - val_loss: 0.0188 - learning_rate: 1.2500e-04
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0246 - val_loss: 0.0186 - learning_rate: 1.2500e-04
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0280 - val_loss: 0.0186 - learning_rate: 1.2500e-04
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.0328 - val_loss: 0.0186 - learning_rate: 1.2500e-04
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0306 - val_loss: 0.0186 - learning_rate: 1.2500e-04
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 0.0327 - val_loss: 0.0186 - learning_rate: 1.2500e-04
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0257 - val_loss: 0.0185 - learning_rate: 1.2500e-04
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0353 - val_loss: 0.0185 - learning_rate: 1.2500e-04
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0348 - val_loss: 0.0184 - learning_rate: 1.2500e-04
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0345 - val_loss: 0.0183 - learning_rate: 1.2500e-04
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.0257 - val_loss: 0.0182 - learning_rate: 1.2500e-04
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0386 - val_loss: 0.0182 - learning_rate: 1.2500e-04
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0262 - val_loss: 0.0182 - learning_rate: 1.2500e-04
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0268 - val_loss: 0.0180 - learning_rate: 1.2500e-04
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0283 - val_loss: 0.0180 - learning_rate: 1.2500e-04
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0387 - val_loss: 0.0180 - learning_rate: 1.2500e-04
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0225 - val_loss: 0.0180 - learning_rate: 1.2500e-04
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.0279 - val_loss: 0.0179 - learning_rate: 1.2500e-04
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0274 - val_loss: 0.0177 - learning_rate: 1.2500e-04
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0275 - val_loss: 0.0177 - learning_rate: 1.2500e-04
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.0240 - val_loss: 0.0176 - learning_rate: 1.2500e-04
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0279 - val_loss: 0.0176 - learning_rate: 1.2500e-04
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0270 - val_loss: 0.0175 - learning_rate: 1.2500e-04
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 0.0376 - val_loss: 0.0175 - learning_rate: 1.2500e-04
# Epoch 64/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0275 - val_loss: 0.0174 - learning_rate: 1.2500e-04
# Epoch 65/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 0.0262 - val_loss: 0.0173 - learning_rate: 1.2500e-04
# Epoch 66/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0273 - val_loss: 0.0172 - learning_rate: 1.2500e-04
# Epoch 67/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0237 - val_loss: 0.0171 - learning_rate: 1.2500e-04
# Epoch 68/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - loss: 0.0279 - val_loss: 0.0171 - learning_rate: 1.2500e-04
# Epoch 69/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0208 - val_loss: 0.0171 - learning_rate: 1.2500e-04
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0326 - val_loss: 0.0172 - learning_rate: 1.2500e-04
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0296 - val_loss: 0.0172 - learning_rate: 1.2500e-04
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0273 - val_loss: 0.0171 - learning_rate: 1.2500e-04
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0341 - val_loss: 0.0170 - learning_rate: 1.2500e-04
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0326 - val_loss: 0.0169 - learning_rate: 1.2500e-04
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0287 - val_loss: 0.0168 - learning_rate: 1.2500e-04
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0277 - val_loss: 0.0166 - learning_rate: 1.2500e-04
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0311 - val_loss: 0.0166 - learning_rate: 1.2500e-04
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0344 - val_loss: 0.0165 - learning_rate: 1.2500e-04
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.0243 - val_loss: 0.0164 - learning_rate: 1.2500e-04
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 0.0283 - val_loss: 0.0164 - learning_rate: 1.2500e-04
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0321 - val_loss: 0.0164 - learning_rate: 1.2500e-04
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0273 - val_loss: 0.0163 - learning_rate: 1.2500e-04
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0340 - val_loss: 0.0163 - learning_rate: 1.2500e-04
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0210 - val_loss: 0.0162 - learning_rate: 1.2500e-04
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0319 - val_loss: 0.0162 - learning_rate: 1.2500e-04
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0375 - val_loss: 0.0162 - learning_rate: 1.2500e-04
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 0.0262 - val_loss: 0.0161 - learning_rate: 1.2500e-04
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.0302 - val_loss: 0.0160 - learning_rate: 1.2500e-04
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0243 - val_loss: 0.0159 - learning_rate: 1.2500e-04
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 0.0349 - val_loss: 0.0159 - learning_rate: 1.2500e-04
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0241 - val_loss: 0.0157 - learning_rate: 1.2500e-04
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.0294 - val_loss: 0.0156 - learning_rate: 1.2500e-04
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.0283 - val_loss: 0.0156 - learning_rate: 1.2500e-04
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 0.0237 - val_loss: 0.0155 - learning_rate: 1.2500e-04
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0320 - val_loss: 0.0155 - learning_rate: 1.2500e-04
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0282 - val_loss: 0.0154 - learning_rate: 1.2500e-04
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 0.0229 - val_loss: 0.0154 - learning_rate: 1.2500e-04
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0246 - val_loss: 0.0154 - learning_rate: 1.2500e-04
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0301 - val_loss: 0.0154 - learning_rate: 1.2500e-04
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.0297 - val_loss: 0.0154 - learning_rate: 1.2500e-04
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 701ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Train Metrics: {'RMSE': 75.42664202100258, 'MAE': 57.20334019507432, 'R²': 0.2527209012840854, 'MAPE': 17.906529291686105}
# Test Metrics: {'RMSE': 61.98560001512649, 'MAE': 47.86720094807942, 'R²': -0.05855304770214542, 'MAPE': 19.483124785726325}

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import math
from urllib.request import urlretrieve

# %%
df=pd.read_csv("Daily_Demand_Forecasting_Orders.csv",delimiter=";",decimal=",")
df.head()
# Out:
#    Week of the month (first week, second, third, fourth or fifth week  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  2
# 4                                                  2
#
#    Day of the week (Monday to Friday) Non-urgent order Urgent order  \
# 0                                   4          316.307      223.270
# 1                                   5          128.633       96.042
# 2                                   6           43.651       84.375
# 3                                   2          171.297      127.667
# 4                                   3           90.532      113.526
#
#   Order type A Order type B Order type C Fiscal sector orders  \
# 0       61.543      175.586      302.448                    0
# 1       38.058       56.037      130.580                    0
# ...

# %%
x_scaler=MinMaxScaler()
x_scaler=x_scaler.fit_transform(df.iloc[:,:-1].values)
y_scaler=MinMaxScaler()
y_scaler=y_scaler.fit_transform(df.iloc[:,-1].values.reshape(-1,1))

# %%
seq_length=7
train_size=int(len(x_scaler)*0.8)

# %%
x_train_data=x_scaler[:train_size]
x_test_data=x_scaler[train_size-seq_length:]
y_train_data=y_scaler[:train_size]
y_test_data=y_scaler[train_size-seq_length:]

# %%
x_train,y_train=[],[]
x_test,y_test=[],[]

# %%
for i in range(len(x_train_data)-seq_length):
    x_train.append(x_train_data[i:i+seq_length])
    y_train.append(y_train_data[i+seq_length])

# %%
for i in range(len(x_test_data)-seq_length):
    x_train.append(x_test_data[i:i+seq_length])
    y_train.append(y_test_data[i+seq_length])
